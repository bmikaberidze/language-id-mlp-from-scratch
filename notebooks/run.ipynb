# %%
from src.lid import LanguageIdentificationModel
model = LanguageIdentificationModel()

# %%
model.preprocess()

# %%
# model.tuning()

# %%
model.train()
# Out:
# Number of unique features:  667
# Numbers of training, validation and test sentences:  126000 36000 18000
# Epoch - 1/4 - Learning rate: 0.0005 - - - - - - - - - - - - - - #
# Epoch - 2/4 - Learning rate: 0.0001 - - - - - - - - - - - - - - #
# Epoch - 3/4 - Learning rate: 2e-05 - - - - - - - - - - - - - - #
# Epoch - 4/4 - Learning rate: 4.000000000000001e-06 - - - - - - - - - - - - - - #

# %%
model.test()
# Out:
# Model's accuracy: 98.12%
